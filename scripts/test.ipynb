# %%
import xarray as xr

# %%
data = xr.load_dataset(
    r"C:\Users\SPEEM\Documents\Python Packages\speem\out\data\jgobbo\2025-09-29-lgtb-0_19-28-34-248966\nc\raw_daq.nc"
)

# %%
data
# Out:
# <xarray.Dataset>
# Dimensions:                               (dim_0: 359, dim_1: 3,
#                                            power_supply-terminal_voltages-time: 5,
#                                            detector-frame_time-time: 3,
#                                            detector-frame-time: 3)
# Coordinates:
#   * power_supply-terminal_voltages-time   (power_supply-terminal_voltages-time) datetime64[ns] ...
#   * detector-frame_time-time              (detector-frame_time-time) datetime64[ns] ...
#   * detector-frame-time                   (detector-frame-time) datetime64[ns] ...
# Dimensions without coordinates: dim_0, dim_1
# Data variables:
#     detector-frame-data                   (dim_0, dim_1) float64 -11.39 ... 3...
#     power_supply-terminal_voltages-step   (power_supply-terminal_voltages-time) int32 ...
#     power_supply-terminal_voltages-point  (power_supply-terminal_voltages-time) int32 ...
# ...

# %%
print(data["detector-frame-data"].data.shape)
print(sum(data["detector-frame-data_lengths"].data))
# Out:
# (359, 3)
# 359
