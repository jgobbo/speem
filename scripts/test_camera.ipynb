# %%
from pylucam import LucamCamera
from pylucam.api import LucamError

from matplotlib import pyplot as plt

# %%
camera = LucamCamera(1)
camera.enable_fast_frames()

# %%
frame = camera.take_fast_frame()

# %%
plt.imshow(frame)
